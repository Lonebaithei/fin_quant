# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime, timedelta
from compat import (
    normalize_timezone, safe_resample, safe_concat, safe_append,
    safe_frequency_conversion, safe_yfinance_download, get_frequency_alias
)

# %%
# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# list of tickers to fetch returns for
tickers = ["NVDA","TSM","LMT","TSM","ADV","AIRI","CAT","COTY",'DIS','ERIC','GNPX','INTC','MU','NOC','RTX','SMCI','STEM','T','TDOC','UGI','UNH','VNQ']

# download returns into a dict: {ticker: returns_series}
stocks = {t: qs.utils.download_returns(t) for t in tickers}

# show sharpe ratio for each ticker
for t, s in stocks.items():
	print(t, qs.stats.sharpe(s))

# or using extend_pandas() on a single series, e.g. NVDA
stocks['NVDA'].sharpe()
# Out:
# NVDA 0.823947154320467
# TSM 0.6036550497139088
# LMT 0.47059880689210687
# ADV -0.48250815646481765
# AIRI 0.5707625574477416
# CAT 0.5382810650146084
# COTY -0.019603031577025122
# DIS 0.5311922822632439
# ERIC 0.38811933584869474
# GNPX 0.16982504041396593
# INTC 0.49851296936064066
# MU 0.5292369979462491
# NOC 0.6051305414419148
# RTX 0.5733037586816996
# SMCI 0.6176449013172949
# STEM 0.11773039497262211
# T 0.5725909567423954
# TDOC 0.12978650318296425
# UGI 0.4841538572764322
# UNH 0.6778160193611824
# VNQ 0.40041210929997334
# np.float64(0.823947154320467)

# %%
# for a single stock, eg NVDA
 qs.plots.snapshot(stocks['NVDA'], title='NVDA Performance', show=True)

# can also be called via:
# stocks['NVDA'].plot_snapshot(title='NVDA Performance', show=True)

# %%
# for the whole portfolio
#for ticker, stock_data in stocks.items():
#    qs.plots.snapshot(stock_data, title=f'{ticker} Performance', show=True)

# %% [markdown]
# Creating a report

# %%
# benchmark can be a pandas Series or ticker
qs.reports.html(stocks['NVDA'], "NVDA")
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# ...
