# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import datetime, timedelta

# %%
# %matplotlib inline
import quantstats as qs

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# fetch the daily returns for a stock
stock = qs.utils.download_returns('NVDA')
stock = qs.utils.download_returns('TSM')
stock = qs.utils.download_returns('LMT')
stock = qs.utils.download_returns('TSM')
stock = qs.utils.download_returns('ADV')
stock = qs.utils.download_returns('AIRI')
stock = qs.utils.download_returns('CAT')
stock = qs.utils.download_returns('COTY')
stock = qs.utils.download_returns('DIS')
stock = qs.utils.download_returns('ERIC')
stock = qs.utils.download_returns('GNPX')
stock = qs.utils.download_returns('INTC')
stock = qs.utils.download_returns('MU')
stock = qs.utils.download_returns('NOC')
stock = qs.utils.download_returns('RTX')
stock = qs.utils.download_returns('SMCI')
stock = qs.utils.download_returns('STEM')
stock = qs.utils.download_returns('T')
stock = qs.utils.download_returns('TDOC')
stock = qs.utils.download_returns('UGI')
stock = qs.utils.download_returns('UNH')
stock = qs.utils.download_returns('VNQ')



# show sharpe ratio
qs.stats.sharpe(stock)

# or using extend_pandas() :)
stock.sharpe()
# Out:
# np.float64(0.3993053308608563)

# %%
qs.plots.snapshot(stock, title='XT_CAPITAL Portfolio Performance', show=True)

# can also be called via:
# stock.plot_snapshot(title='Facebook Performance', show=True)
# Out:
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
# findfont: Font family 'Arial' not found.
